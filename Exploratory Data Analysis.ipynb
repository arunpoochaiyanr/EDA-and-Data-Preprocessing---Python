# %% [markdown]
# <font size=5 color='Red'> **Exploratory Data Analysis on YouTube Videos** </font>

# %% [markdown]
# <font size=4 color='red'> **Great Learning** </font>

# %% [markdown]
# <font size=3 color='blue'> **Arun Poochaiyan R (GLCA DA Online August 2023)** </font>

# %% [markdown]
# #### 1.Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1.Reading the dataset

# %%
df = pd.read_csv('youtube_dislike_dataset.csv')
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# #### 1.Displaying top 5 values

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %% [markdown]
# #### 1.Displaying bottom 5 values

# %%
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# #### 2.Checking info, shape and dtypes of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
df.shape
# Out:
# (37422, 12)

# %% [markdown]
# <font size=3 color='blue'> **Inference:** </font>
# <font size=3 color='black'> There are 37,422 number of rows and  12 columns </font>

# %%
df.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %% [markdown]
# <font size=3 color='blue'> **Inference:** </font>
# <font size=3 color='black'> The dataset contains both integer and object datatypes </font>

# %% [markdown]
# #### 3.Checking for the missing values

# %%
missing = df.isnull().sum()
missing
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %% [markdown]
# #### 3.Percentage of missing values in 'comments' column

# %%
print('The percentage of missing values in "comments" column is' ,(missing['comments']/len(df))*100)
# Out:
# The percentage of missing values in "comments" column is 0.4222115333226444

# %% [markdown]
# #### 3.Columns available before dropping the 'comments' column

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description', 'comments'],
#       dtype='object')

# %% [markdown]
# #### 3.Dropping the 'comments' column

# %%
df.drop(['comments'], axis = 1, inplace = True)
df.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# dtype: object

# %% [markdown]
# #### 4.Statistical summary of numerical data types

# %%
df.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %% [markdown]
# <font size=2 color='blue'> **Inference:** </font>
# <font size=2 color='black'> Based on the Statistical summary, we can derive the following for numerical data </font>

# %% [markdown]
# 1) The are totally 37422 trending videos from August 2020 to December 2021 from the countries USA, Canada and Great Britain and contains the numerical data such as view_count, likes, dislikes and comment_count
# 2) The maximum view of a particular video is 1.322797 billion and the minimum view of a particular video is 20,368.
# 3) The minimum number of likes for a video is 0 and the maximum number of likes is over 31 million
# 4) The minimum number of dislikes for a video is 0 and the maximum number of dislikes for another video 2.39 million
# 5) The minimum number of comments for a video is 0 and the maximum number of comments for a video is over 16.07 million.
# 6) On average, each video received 166814 likes and 4989 dislikes.
# 7) On average, each video received a count of 5.6 million.
# 8) And the the average comments for a video is 9925.

# %% [markdown]
# #### 4.Statistical summary of categorical data type

# %%
df.describe(percentiles =[0, .25, .5, .75,1] ,include = 'object')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description
# count                 37422  37422       37422
# unique                36772  28799       35630
# top     2020-10-16 04:00:10
# freq                      6   3817         589

# %% [markdown]
# <font size=2 color='blue'> **Inference:** </font>
# <font size=2 color='black'> Based on the Statistical summary, we can derive the following for categorical data  </font>

# %% [markdown]
# 1) There are 37264 unique video ids, titles, channel ids, channel titles, publication dates, tags, descriptions and comments in the dataset and these are of categorical data type.
# 2) Out of 37264 data, only 37113 has unique video titles, which means 151 videos have the similiar titles.
# 3) Out of 37264 data, there are obly 10961 unique channel ids. Which means there are several videos from 10961 unique and contributes a total of 37264 data.
# 4) Out 37264 data, only 10883 has unique channel_titles.
# 5) Only 28799 data/ videos used different/unique tags. Whereas the remaining 8623 data contains similiar tags to that of other videos.
# 6) The most frequent channel id is "UCNAf1k0yIjyGu3k9BwAg3lg" and its channel title is "Sky Sports Football". This video was published at " 2020-10-16 04:00:10	".

# %% [markdown]
# #### 5.Coversion of column 'published_at' to datetime data type

# %%
df["published_at"]= pd.to_datetime(df["published_at"])

# %%
df["published_at"]
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %% [markdown]
# #### 6.Creating new column 'published_month' using the data from column 'pulished_at'

# %%
df['published_month']=df['published_at'].dt.month

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# #### 7.Replacing the number into names of months

# %%
df['published_month'].replace({1:'Jan', 2:'Feb', 3:'Mar',4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'}, inplace = True)

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# #### 8.Arraging the months in descending order based on total video count

# %%
monthly_video_count = df.groupby('published_month')['video_id'].count().sort_values(ascending=False)
print(monthly_video_count)
# Out:
# published_month
# Oct    4991
# Sep    4880
# Nov    4851
# Aug    4262
# Dec    3072
# Jul    2340
# Jun    2316
# Mar    2258
# Feb    2137
# Apr    2126
# Jan    2108
# May    2081
# Name: video_id, dtype: int64

# %% [markdown]
# #### 9.Finding the count of unique video_id, channel_id, channel_title

# %%
unique_video_id_Count = df["video_id"].nunique() 

unique_channel_id_count =  df["channel_id"].nunique()

unique_channel_title_count = df["channel_title"].nunique()

print("The Unique video_id_ count is",unique_video_id_Count) 

print("The Unique channel_id count is",unique_channel_id_count)

print("The Unique channel_title count is",unique_channel_title_count)
# Out:
# The Unique video_id_ count is 37422
# The Unique channel_id count is 10961
# The Unique channel_title count is 10883

# %% [markdown]
# #### 10.Top and Bottom 10 channels

# %%
top_10 = df.groupby(['channel_title'])['title'].count().sort_values(ascending = False).head(10)
top_10
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: title, dtype: int64

# %%
bottom_10 = df.groupby(['channel_title'])['title'].count().sort_values(ascending = False).tail(10)
bottom_10
# Out:
# channel_title
# Karchez           1
# Karate Combat     1
# Kaptain Kuba      1
# Kanye West        1
# Kannur kitchen    1
# Kannada Cinema    1
# KanalD            1
# Kanak News        1
# Kamille Ramos     1
# zoom              1
# Name: title, dtype: int64

# %% [markdown]
# #### 11. Videos with Maximum and Minimum Likes

# %%
max_likes = df.sort_values('likes', ascending=False)
max_likes = max_likes.iloc[0]['title']
print(f'Title of video with maximum likes: {max_likes}')
# Out:
# Title of video with maximum likes: BTS () 'Dynamite' Official MV

# %% [markdown]
# <font size=2 color='blue'> **Inference:** </font>
# <font size=2 color='black'> The video that got the maximum number of likes is "BTS () 'Dynamite' Official MV" and has got 31.86 million likes </font>

# %%
min_likes = df.sort_values('likes')
min_likes = min_likes.iloc[0]['title']
print(f'Title of video with minimum likes is: {min_likes}')
# Out:
# Title of video with minimum likes is: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# <font size=2 color='blue'> **Inference:** </font>
# <font size=2 color='black'> The video that got the minimum number of likes is "Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News" and has 0 got likes </font>

# %% [markdown]
# #### 12. Videos with Maximum and Minimum Dislikes

# %%
max_dislikes = df.sort_values('dislikes', ascending=False)
max_dislikes = max_dislikes.iloc[0]['title']
print(f'Title of the video with maximum dislikes is: {max_dislikes}')
# Out:
# Title of the video with maximum dislikes is: Cuties | Official Trailer | Netflix

# %% [markdown]
# <font size=2 color='blue'> **Inference:** </font>
# <font size=2 color='black'> The video that got the maximum dislike is "Cuties | Official Trailer | Netflix" and has got 2.39 Million dislikes </font>

# %%
min_dislikes = df.sort_values('dislikes', ascending=True)
min_dislikes = min_dislikes.iloc[0]['title']
print(f'Title of the video with minimun dislikes is: {min_dislikes}')
# Out:
# Title of the video with minimun dislikes is: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# <font size=2 color='blue'> **Inference:** </font>
# <font size=2 color='black'> The video that got the minimum dislike is "Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News" and has got 0 dislikes </font>

# %% [markdown]
# #### 13.Effect of number of views for a video by the people based on Dislikes

# %%
corr_view_dislikes = df['view_count'].corr(df['dislikes'])
print(corr_view_dislikes)
# Out:
# 0.6844687753905547

# %%
import matplotlib.pyplot as plot

# %%
plot.scatter(df['view_count'], df['dislikes'])
plot.xlabel('Views')
plot.ylabel('Dislikes')
plot.title('Correlation between Views and Dislikes')
plot.show()

# %% [markdown]
# <font size=2 color='blue'> **Inference:** </font>
# <font size=2 color='black'> From the corelation coefficient 0.68445 and scatter plot, we could see that the relationship between the number of views and number of dislikes is moderate. And also the relationship is perfectly linear. Also the number views has some effect on the number of dislikes or the the number of views does have some effects on the number of dislikes of the video </font>

# %% [markdown]
# #### 14.Videos published on January

# %%
jan_videos = df[df['published_month'] == 'Jan']
display(jan_videos)
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
print("Summary statistics of videos published in January:")
jan_videos.describe()
# Out:
# Summary statistics of videos published in January:
#                         published_at    view_count         likes  \
# count                           2108  2.108000e+03  2.108000e+03
# mean   2021-01-17 11:32:44.133301504  4.976449e+06  1.315030e+05
# min              2021-01-01 00:00:54  2.845000e+04  2.800000e+01
# 25%    2021-01-09 22:42:18.750000128  4.322335e+05  1.032400e+04
# 50%              2021-01-17 18:35:30  1.147500e+06  3.173900e+04
# 75%    2021-01-25 14:00:07.750000128  3.227483e+06  1.076512e+05
# max              2021-01-31 23:15:09  6.203274e+08  7.828036e+06
# std                              NaN  2.055331e+07  3.886887e+05
#
#             dislikes  comment_count
# count    2108.000000   2.108000e+03
# mean     3614.568311   8.923385e+03
# min         3.000000   0.000000e+00
# 25%       249.000000   8.747500e+02
# 50%       729.000000   2.328500e+03
# 75%      2243.250000   6.302000e+03
# max    409144.000000   1.095119e+06
# ...

# %%
print(f"There were totally {len(jan_videos)} videos published in the month - January")
# Out:
# There were totally 2108 videos published in the month - January
